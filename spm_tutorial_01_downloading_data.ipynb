# %% [markdown]
# # SPM Tutorial #1: Downloading the Data

# %%
from pathlib import Path

bids_root = Path("ds000102")
bold_files = sorted(bids_root.glob("sub-*/func/*_bold.nii.gz"))
print(f"Found {len(bold_files)} BOLD files")
print(f"Dataset location: {bids_root.absolute()}")
print(f"Example file: {bold_files[0] if bold_files else 'None'}")
# Out:
# Found 52 BOLD files
# Dataset location: /Users/abhishekgautam/Desktop/Research Works (paper: patent: project: review)/AcSIR (PhD)/SPM/ds000102
# Example file: ds000102/sub-01/func/sub-01_task-flanker_run-1_bold.nii.gz

# %%
# %pip install datalad
# Out:
# Collecting datalad
#   Downloading datalad-1.3.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: platformdirs in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (3.10.0)
# Requirement already satisfied: chardet>=3.0.4 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (4.0.0)
# Requirement already satisfied: distro in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (1.9.0)
# Collecting iso8601 (from datalad)
#   Using cached iso8601-2.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting humanize (from datalad)
#   Downloading humanize-4.15.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting fasteners>=0.14 (from datalad)
#   Using cached fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: packaging in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (25.0)
# Collecting patool>=1.7 (from datalad)
#   Downloading patool-4.0.4-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.32.0 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (4.65.0)
# Collecting annexremote (from datalad)
#   Using cached annexremote-1.6.6-py3-none-any.whl.metadata (6.5 kB)
# Collecting looseversion (from datalad)
#   Using cached looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting boto3 (from datalad)
#   Downloading boto3-1.42.43-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: keyring!=23.9.0,>=20.0 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (23.13.1)
# Collecting keyrings.alt (from datalad)
#   Using cached keyrings.alt-5.0.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: msgpack in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (1.0.3)
# Requirement already satisfied: requests>=1.2 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from datalad) (2.31.0)
# Collecting python-gitlab (from datalad)
#   Downloading python_gitlab-8.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: jaraco.classes in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad) (3.2.1)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=4.11.4->keyring!=23.9.0,>=20.0->datalad) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from requests>=1.2->datalad) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from requests>=1.2->datalad) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from requests>=1.2->datalad) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from requests>=1.2->datalad) (2023.7.22)
# Collecting botocore<1.43.0,>=1.42.43 (from boto3->datalad)
#   Downloading botocore-1.42.43-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from boto3->datalad) (0.10.0)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3->datalad)
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.43->boto3->datalad) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.43->boto3->datalad) (1.17.0)
# Requirement already satisfied: more-itertools in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from jaraco.classes->keyring!=23.9.0,>=20.0->datalad) (8.12.0)
# Collecting jaraco.context (from keyrings.alt->datalad)
#   Using cached jaraco_context-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting backports.tarfile (from jaraco.context->keyrings.alt->datalad)
#   Using cached backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting requests>=1.2 (from datalad)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/abhishekgautam/anaconda3/lib/python3.11/site-packages (from python-gitlab->datalad) (1.0.0)
# Downloading datalad-1.3.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.0 MB/s  0:00:0036m-:--:--
# Using cached fasteners-0.20-py3-none-any.whl (18 kB)
# Downloading patool-4.0.4-py2.py3-none-any.whl (88 kB)
# Using cached annexremote-1.6.6-py3-none-any.whl (25 kB)
# Downloading boto3-1.42.43-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.43-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 3.2 MB/s  0:00:04 eta 0:00:01
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading humanize-4.15.0-py3-none-any.whl (132 kB)
# Using cached iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Using cached keyrings.alt-5.0.2-py3-none-any.whl (17 kB)
# Using cached jaraco_context-6.1.0-py3-none-any.whl (7.1 kB)
# Using cached backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Using cached looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading python_gitlab-8.0.0-py3-none-any.whl (144 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Installing collected packages: looseversion, annexremote, requests, patool, iso8601, humanize, fasteners, backports.tarfile, jaraco.context, botocore, s3transfer, python-gitlab, keyrings.alt, boto3, datalad
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.76
#     Uninstalling botocore-1.29.76:0m╺━━━━━━━━━━━━━━━  9/15 [botocore]
#       Successfully uninstalled botocore-1.29.76━━━━━━━━━━━━━━━  9/15 [botocore]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [datalad]4/15 [datalad]er]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires python-dateutil==2.8.2, but you have python-dateutil 2.9.0.post0 which is incompatible.
# conda-repo-cli 1.0.75 requires PyYAML==6.0.1, but you have pyyaml 6.0 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.5 which is incompatible.
# langchain-community 0.2.4 requires numpy<2,>=1, but you have numpy 2.3.5 which is incompatible.
# tensorflow 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.5 which is incompatible.
# langchain 0.2.3 requires numpy<2,>=1, but you have numpy 2.3.5 which is incompatible.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.42.43 which is incompatible.
# Successfully installed annexremote-1.6.6 backports.tarfile-1.2.0 boto3-1.42.43 botocore-1.42.43 datalad-1.3.1 fasteners-0.20 humanize-4.15.0 iso8601-2.1.0 jaraco.context-6.1.0 keyrings.alt-5.0.2 looseversion-1.3.0 patool-4.0.4 python-gitlab-8.0.0 requests-2.32.5 s3transfer-0.16.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import shutil
import subprocess
import sys
import importlib.util
from pathlib import Path

bids_root = Path("ds000102")
sample_file = "sub-01/func/sub-01_task-flanker_run-1_bold.nii.gz"
datalad_cli = shutil.which("datalad")
datalad_module = importlib.util.find_spec("datalad")

if not bids_root.exists():
    print("Dataset path not found. Ensure ds000102 is in the project root.")
elif datalad_cli is None and datalad_module is None:
    print("datalad not found in PATH or kernel. Install datalad to fetch files.")
else:
    print(f"Fetching {sample_file}...")
    if datalad_cli is not None:
        cmd = [datalad_cli, "get", sample_file]
    else:
        cmd = [sys.executable, "-m", "datalad", "get", sample_file]
    result = subprocess.run(
        cmd,
        cwd=bids_root,
        capture_output=True,
        text=True
    )
    if result.returncode == 0:
        print("File fetched successfully!")
    else:
        print(f"Return code: {result.returncode}")
        if result.stderr:
            print(f"Error: {result.stderr}")
        if result.stdout:
            print(f"Output: {result.stdout}")
# Out:
# Fetching sub-01/func/sub-01_task-flanker_run-1_bold.nii.gz...
# File fetched successfully!
